# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split, KFold, cross_val_score  #***
from sklearn.preprocessing import LabelEncoder, OneHotEncoder, StandardScaler, MinMaxScaler
from sklearn.compose import  ColumnTransformer, make_column_transformer, make_column_selector
from sklearn.metrics import r2_score, log_loss, accuracy_score, roc_auc_score, f1_score, log_loss

from sklearn.tree import DecisionTreeRegressor, plot_tree, DecisionTreeClassifier
from sklearn.linear_model import LogisticRegression, LinearRegression, ElasticNet, Ridge
from sklearn.naive_bayes import GaussianNB
from sklearn.neighbors import KNeighborsClassifier
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.svm import SVC
from xgboost import XGBClassifier,  XGBRegressor
from sklearn.pipeline import Pipeline

from sklearn.ensemble import RandomForestClassifier, RandomForestRegressor, StackingClassifier, StackingRegressor

from tqdm import tqdm  # Provides the progress of model running
import os
import warnings
warnings.filterwarnings('ignore')

# %%
concrete = pd.read_csv(r"D:\Machine_Learning_CDAC-AI\a] Datasets\Concrete_Data.csv")
X , y = concrete.drop(['Strength'], axis=1), concrete['Strength']

lr = LinearRegression()
kfold = KFold(n_splits=5, shuffle=True, random_state=26)
results = cross_val_score(lr, X, y, cv=kfold)  # Finds r2_score by default
print(results)
print(np.mean(results))
# Out:
# [0.61474372 0.56604898 0.59335131 0.61186382 0.62837728]
# 0.602877022245518

# %%
alphas = np.linspace(0.001, 10, 30)
scores=[]
for a in tqdm(alphas):
    ridge = Ridge(alpha=a)
    kfold = KFold(n_splits=5, shuffle=True, random_state=26) 
    scores.append([a, cross_val_score(ridge, X, y, cv=kfold).mean()])
    
df_scores = pd.DataFrame(scores, columns=['alpha', 'cross_val_score' ])
df_scores.sort_values(['cross_val_score'], ascending=False).head()
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████| 30/30 [00:03<00:00,  9.70it/s]
#         alpha  cross_val_score
# 29  10.000000         0.602878
# 28   9.655207         0.602878
# 27   9.310414         0.602878
# 26   8.965621         0.602878
# 25   8.620828         0.602878

# %%
alphas = np.linspace(0.001, 10, 30)
scores=[]
for a in tqdm(alphas):
    ridge = Ridge(alpha=a)
    results = cross_val_score(ridge, X, y, cv=kfold) 
    scores.append([a, np.mean(results)])
    print(results)
    
df_scores = pd.DataFrame(scores, columns=['alpha', 'cross_val_score' ])
df_scores.sort_values(['cross_val_score'], ascending=False).head()
# Out:
#   7%|█████▌                                                                             | 2/30 [00:00<00:03,  8.81it/s]
# [0.61474372 0.56604898 0.59335131 0.61186383 0.62837728]
# [0.61474377 0.56604882 0.59335126 0.61186417 0.62837729]
# [0.61474383 0.56604866 0.59335121 0.61186452 0.62837729]
#  20%|████████████████▌                                                                  | 6/30 [00:00<00:02, 10.32it/s]
# [0.61474389 0.5660485  0.59335115 0.61186486 0.6283773 ]
# [0.61474395 0.56604835 0.5933511  0.61186521 0.6283773 ]
# [0.61474401 0.56604819 0.59335105 0.61186555 0.62837731]
#  27%|██████████████████████▏                                                            | 8/30 [00:00<00:02, 10.31it/s]
# [0.61474406 0.56604803 0.593351   0.6118659  0.62837731]
# [0.61474412 0.56604787 0.59335094 0.61186624 0.62837732]
# [0.61474418 0.56604772 0.59335089 0.61186659 0.62837732]
#  40%|████████████████████████████████▊                                                 | 12/30 [00:01<00:01, 10.16it/s]
# [0.61474424 0.56604756 0.59335084 0.61186693 0.62837733]
# [0.6147443  0.5660474  0.59335079 0.61186728 0.62837734]
# [0.61474435 0.56604724 0.59335073 0.61186762 0.62837734]
#  47%|██████████████████████████████████████▎                                           | 14/30 [00:01<00:01, 10.32it/s]
# [0.61474441 0.56604708 0.59335068 0.61186797 0.62837735]
# [0.61474447 0.56604693 0.59335063 0.61186831 0.62837735]
# [0.61474453 0.56604677 0.59335058 0.61186866 0.62837736]
#  60%|█████████████████████████████████████████████████▏                                | 18/30 [00:01<00:01, 10.89it/s]
# [0.61474459 0.56604661 0.59335053 0.611869   0.62837736]
# [0.61474464 0.56604645 0.59335047 0.61186935 0.62837737]
# [0.6147447  0.56604629 0.59335042 0.61186969 0.62837737]
#  67%|██████████████████████████████████████████████████████▋                           | 20/30 [00:01<00:00, 10.93it/s]
# [0.61474476 0.56604614 0.59335037 0.61187004 0.62837738]
# [0.61474482 0.56604598 0.59335032 0.61187038 0.62837738]
# [0.61474488 0.56604582 0.59335026 0.61187073 0.62837739]
#  73%|████████████████████████████████████████████████████████████▏                     | 22/30 [00:02<00:00, 10.22it/s]
# [0.61474493 0.56604566 0.59335021 0.61187107 0.62837739]
# [0.61474499 0.56604551 0.59335016 0.61187142 0.6283774 ]
#  83%|████████████████████████████████████████████████████████████████████▎             | 25/30 [00:02<00:00,  9.15it/s]
# [0.61474505 0.56604535 0.59335011 0.61187176 0.6283774 ]
# [0.61474511 0.56604519 0.59335005 0.61187211 0.62837741]
#  90%|█████████████████████████████████████████████████████████████████████████▊        | 27/30 [00:02<00:00,  8.67it/s]
# [0.61474516 0.56604503 0.59335    0.61187245 0.62837741]
# [0.61474522 0.56604488 0.59334995 0.61187279 0.62837742]
# [0.61474528 0.56604472 0.5933499  0.61187314 0.62837742]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 30/30 [00:03<00:00,  9.65it/s]
# [0.61474534 0.56604456 0.59334984 0.61187348 0.62837743]
# [0.6147454  0.5660444  0.59334979 0.61187383 0.62837743]
#         alpha  cross_val_score
# 29  10.000000         0.602878
# 28   9.655207         0.602878
# 27   9.310414         0.602878
# 26   8.965621         0.602878
# 25   8.620828         0.602878

# %%
alphas = np.linspace(0.001, 10, 30)
ratios = np.linspace(0.001,1,10) 
scores=[]
for a in tqdm(alphas):
    for r in ratios:
        el = ElasticNet(alpha=a, l1_ratio=r)
        results = cross_val_score(el, X, y, cv=kfold) 
        scores.append([a, r, np.mean(results)])
        print(results)
# Out:
#   0%|                                                                                           | 0/30 [00:00<?, ?it/s]
# [0.61474385 0.5660486  0.59335119 0.61186465 0.62837729]
# [0.61474388 0.5660484  0.59335115 0.61186479 0.62837729]
# [0.61474391 0.56604819 0.59335112 0.61186493 0.62837729]
# [0.61474395 0.56604799 0.59335109 0.61186507 0.62837729]
# [0.61474398 0.56604779 0.59335105 0.61186521 0.62837729]
# [0.61474401 0.56604759 0.59335102 0.61186535 0.62837729]
# [0.61474404 0.56604738 0.59335099 0.61186549 0.62837729]
# [0.61474407 0.56604718 0.59335095 0.61186563 0.62837729]
#   3%|██▊                                                                                | 1/30 [00:01<00:36,  1.25s/it]
# [0.6147441  0.56604698 0.59335092 0.61186577 0.62837729]
# [0.61474413 0.56604677 0.59335088 0.6118659  0.62837729]
# [0.61478869 0.56592152 0.59330686 0.61213675 0.62837837]
# [0.61479801 0.56585164 0.59329418 0.6121829  0.62837672]
# [0.61480712 0.56578081 0.59328109 0.61222904 0.62837475]
df_scores = pd.DataFrame(scores, columns=['alpha', 'l1_ratio', 'cross_val_score' ])
df_scores.sort_values(['cross_val_score'], ascending=False).head()
# Out:
#         alpha  l1_ratio  cross_val_score
# 80   2.759345     0.001         0.602982
# 70   2.414552     0.001         0.602981
# 90   3.104138     0.001         0.602981
# 100  3.448931     0.001         0.602978
# 60   2.069759     0.001         0.602977

# %% [markdown]
# ### Changing Scoring Parameter
# #### `scoring` as RMSE

# %%
# from string_name_scores
alphas = np.linspace(0.001, 10, 30)
ratios = np.linspace(0.001,1,10) 
scores=[]
for a in tqdm(alphas):
    for r in ratios:
        el = ElasticNet(alpha=a, l1_ratio=r)
        results = cross_val_score(el, X, y, cv=kfold, scoring='neg_root_mean_squared_error')  # why 'neg': optimizer uses bigger the better in negative way
        scores.append([a, r, np.mean(results)])
df_scores = pd.DataFrame(scores, columns=['alpha', 'l1_ratio', 'root_mean_squared_error' ])
df_scores.sort_values(['root_mean_squared_error'], ascending=False).head()
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████| 30/30 [00:12<00:00,  2.45it/s]
#         alpha  l1_ratio  root_mean_squared_error
# 90   3.104138     0.001               -10.456384
# 100  3.448931     0.001               -10.456385
# 80   2.759345     0.001               -10.456410
# 110  3.793724     0.001               -10.456410
# 120  4.138517     0.001               -10.456456

# %%
features = [2,3,4,5,6,7]
scores=[]

for f in features:
    rf = RandomForestRegressor(random_state=26, max_features=f )
    results = cross_val_score(rf, X, y, cv=kfold, scoring='neg_root_mean_squared_error') 
    scores.append([f, np.mean(results)])
df_scores = pd.DataFrame(scores, columns=['features', 'root_mean_squared_error' ])
df_scores.sort_values(['root_mean_squared_error'], ascending=False).head()
# Out:
#    features  root_mean_squared_error
# 2         4                -4.751942
# 3         5                -4.754536
# 4         6                -4.790249
# 1         3                -4.794503
# 5         7                -4.814700

# %% [markdown]
# ## Housing Dataset

# %%
housing = pd.read_csv(r"D:\Machine_Learning_CDAC-AI\a] Datasets\Housing.csv")
X , y = housing.drop(['price'], axis=1), housing['price']

# %%
# to increase the speed remove sparse_output, set_output

# ohe=OneHotEncoder(sparse_output=False,drop="first").set_output(transform="pandas")
# trans = ColumnTransformer(transformers=[("OHE", ohe, make_column_selector(dtype_include=object))],     
#                           remainder="passthrough",verbose_feature_names_out=False).set_output(transform="pandas")

ohe=OneHotEncoder(drop="first")

trans = ColumnTransformer(transformers=[("OHE", ohe, make_column_selector(dtype_include=object))],     
                          remainder="passthrough", verbose_feature_names_out=False)

# %%
features = [2,3,4,5,6,7]
scores=[]

for f in tqdm(features):
    rf = RandomForestRegressor(random_state=26, max_features=f )
    pipe = Pipeline([('OHE',trans), ('RF',rf)])
    results = cross_val_score(pipe, X, y, cv=kfold, scoring='neg_root_mean_squared_error') 
    scores.append([f, np.mean(results)])
df_scores = pd.DataFrame(scores, columns=['features', 'root_mean_squared_error' ])
df_scores.sort_values(['root_mean_squared_error'], ascending=False).head()
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████████| 6/6 [00:05<00:00,  1.00it/s]
#    features  root_mean_squared_error
# 2         4            -1.098025e+06
# 1         3            -1.104888e+06
# 0         2            -1.117384e+06
# 3         5            -1.118908e+06
# 4         6            -1.129874e+06
