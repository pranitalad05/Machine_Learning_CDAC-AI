# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split, KFold, cross_val_score, GridSearchCV  #***
from sklearn.preprocessing import LabelEncoder, OneHotEncoder, StandardScaler, MinMaxScaler
from sklearn.compose import  ColumnTransformer, make_column_transformer, make_column_selector
from sklearn.metrics import r2_score, log_loss, accuracy_score, roc_auc_score, f1_score, log_loss

from sklearn.tree import DecisionTreeRegressor, plot_tree, DecisionTreeClassifier
from sklearn.linear_model import LogisticRegression, LinearRegression, ElasticNet, Ridge
from sklearn.naive_bayes import GaussianNB
from sklearn.neighbors import KNeighborsClassifier, KNeighborsRegressor
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.svm import SVC
from xgboost import XGBClassifier, XGBRegressor
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer 

from sklearn.ensemble import RandomForestClassifier, RandomForestRegressor, StackingClassifier, StackingRegressor

from tqdm import tqdm  # Provides the progress of model running
import os
import warnings
warnings.filterwarnings('ignore')

# %%
concrete = pd.read_csv(r"D:\Machine_Learning_CDAC-AI\a] Datasets\Concrete_Data.csv")
X , y = concrete.drop(['Strength'], axis=1), concrete['Strength']

# %%
kfold = KFold(n_splits=5, shuffle=True, random_state=26)

# %%
alphas = np.linspace(0.001, 10, 30)
params = {'alpha':alphas}
ridge = Ridge()
gcv = GridSearchCV(estimator=ridge, param_grid=params, cv=kfold)
gcv.fit(X, y)
pd_cv = pd.DataFrame(gcv.cv_results_)
pd_cv.head()
# Out:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time  param_alpha  \
# 0       0.009378      0.000878         0.006476        0.000465     0.001000
# 1       0.009261      0.000826         0.005926        0.000932     0.345793
# 2       0.008242      0.000790         0.005868        0.001370     0.690586
# 3       0.008482      0.000804         0.005326        0.001210     1.035379
# 4       0.012324      0.001009         0.008755        0.001754     1.380172
#
#                           params  split0_test_score  split1_test_score  \
# 0               {'alpha': 0.001}           0.614744           0.566049
# 1  {'alpha': 0.3457931034482759}           0.614744           0.566049
# 2  {'alpha': 0.6905862068965518}           0.614744           0.566049
# 3  {'alpha': 1.0353793103448277}           0.614744           0.566049
# 4  {'alpha': 1.3801724137931035}           0.614744           0.566048
#
#    split2_test_score  split3_test_score  split4_test_score  mean_test_score  \
# 0           0.593351           0.611864           0.628377         0.602877
# 1           0.593351           0.611864           0.628377         0.602877
# 2           0.593351           0.611865           0.628377         0.602877
# 3           0.593351           0.611865           0.628377         0.602877
# 4           0.593351           0.611865           0.628377         0.602877
#
#    std_test_score  rank_test_score
# 0        0.021535               30
# 1        0.021536               29
# 2        0.021536               28
# 3        0.021536               27
# 4        0.021536               26

# %%
gcv.best_params_, gcv.best_score_
# Out:
# ({'alpha': np.float64(10.0)}, np.float64(0.6028781702961167))

# %%
alphas = np.linspace(0.001, 10, 30)
ratios = np.linspace(0.001,1,10) 

params = {'alpha':alphas,'l1_ratio':ratios}

el = ElasticNet()
gcv = GridSearchCV(estimator=el, param_grid=params, cv=kfold)
gcv.fit(X, y)
pd_cv = pd.DataFrame(gcv.cv_results_)
pd_cv.head()
gcv.best_params_, gcv.best_score_
# Out:
# ({'alpha': np.float64(2.759344827586207), 'l1_ratio': np.float64(0.001)},
#  np.float64(0.6029818143707282))

# %%
params = {'alpha':np.linspace(0.001, 10, 30), 'l1_ratio':np.linspace(0.001,1,10)}

el = ElasticNet()
gcv = GridSearchCV(estimator=el, param_grid=params, cv=kfold)
gcv.fit(X, y)
pd_cv = pd.DataFrame(gcv.cv_results_)
pd_cv.head()
gcv.best_params_, gcv.best_score_
# Out:
# ({'alpha': np.float64(2.759344827586207), 'l1_ratio': np.float64(0.001)},
#  np.float64(0.6029818143707282))

# %%
params = {'alpha':np.linspace(0.001, 10, 30), 'l1_ratio':np.linspace(0.001,1,10)}

el = ElasticNet()
gcv = GridSearchCV(estimator=el, param_grid=params, cv=kfold, scoring='neg_root_mean_squared_error')
gcv.fit(X, y)
pd_cv = pd.DataFrame(gcv.cv_results_)
pd_cv.head()
gcv.best_params_, gcv.best_score_
# Out:
# ({'alpha': np.float64(3.104137931034483), 'l1_ratio': np.float64(0.001)},
#  np.float64(-10.456383568226837))

# %%
features = [2,3,4,5,6,7]
params = {'max_features':features}
rf = RandomForestRegressor(random_state=26)

gcv = GridSearchCV(estimator=rf, param_grid=params, cv=kfold, scoring='neg_root_mean_squared_error') 
gcv.fit(X, y)
pd_cv = pd.DataFrame(gcv.cv_results_)
pd_cv.head
gcv.best_params_, gcv.best_score_
# Out:
# ({'max_features': 4}, np.float64(-4.751942056038116))

# %%
features = [2,3,4,5,6,7]
params = {'max_features':features}
rf = RandomForestRegressor(random_state=26)

gcv = GridSearchCV(estimator=rf, param_grid=params, cv=kfold, verbose=3, scoring='neg_root_mean_squared_error')  # verbose=1 gives information (max=3)
gcv.fit(X, y)
pd_cv = pd.DataFrame(gcv.cv_results_)
pd_cv.head
gcv.best_params_, gcv.best_score_
# Out:
# Fitting 5 folds for each of 6 candidates, totalling 30 fits
# [CV 1/5] END ...................max_features=2;, score=-6.111 total time=   1.0s
# [CV 2/5] END ...................max_features=2;, score=-4.679 total time=   1.0s
# [CV 3/5] END ...................max_features=2;, score=-4.431 total time=   1.0s
# [CV 4/5] END ...................max_features=2;, score=-6.111 total time=   0.9s
# [CV 5/5] END ...................max_features=2;, score=-4.112 total time=   0.9s
# [CV 1/5] END ...................max_features=3;, score=-5.645 total time=   1.2s
# [CV 2/5] END ...................max_features=3;, score=-4.140 total time=   1.1s
# [CV 3/5] END ...................max_features=3;, score=-4.298 total time=   0.6s
# [CV 4/5] END ...................max_features=3;, score=-5.822 total time=   0.2s
# [CV 5/5] END ...................max_features=3;, score=-4.067 total time=   0.3s
# [CV 1/5] END ...................max_features=4;, score=-5.565 total time=   0.3s
# [CV 2/5] END ...................max_features=4;, score=-4.136 total time=   0.3s
# [CV 3/5] END ...................max_features=4;, score=-4.287 total time=   0.2s
# [CV 4/5] END ...................max_features=4;, score=-5.723 total time=   0.3s
# [CV 5/5] END ...................max_features=4;, score=-4.048 total time=   0.3s
# [CV 1/5] END ...................max_features=5;, score=-5.686 total time=   0.3s
# [CV 2/5] END ...................max_features=5;, score=-4.122 total time=   0.3s
# [CV 3/5] END ...................max_features=5;, score=-4.276 total time=   0.3s
# [CV 4/5] END ...................max_features=5;, score=-5.701 total time=   0.3s
# [CV 5/5] END ...................max_features=5;, score=-3.988 total time=   0.3s
# [CV 1/5] END ...................max_features=6;, score=-5.588 total time=   0.3s
# [CV 2/5] END ...................max_features=6;, score=-4.162 total time=   0.3s
# [CV 3/5] END ...................max_features=6;, score=-4.269 total time=   0.3s
# [CV 4/5] END ...................max_features=6;, score=-5.827 total time=   0.3s
# [CV 5/5] END ...................max_features=6;, score=-4.106 total time=   0.4s
# [CV 1/5] END ...................max_features=7;, score=-5.501 total time=   0.3s
# [CV 2/5] END ...................max_features=7;, score=-4.198 total time=   0.3s
# [CV 3/5] END ...................max_features=7;, score=-4.385 total time=   0.3s
# [CV 4/5] END ...................max_features=7;, score=-5.881 total time=   0.3s
# [CV 5/5] END ...................max_features=7;, score=-4.109 total time=   0.3s
# ({'max_features': 4}, np.float64(-4.751942056038116))

# %%
# n_jobs
features = [2,3,4,5,6,7]
params = {'max_features':features}
rf = RandomForestRegressor(random_state=26)

gcv = GridSearchCV(estimator=rf, param_grid=params, cv=kfold, verbose=3, n_jobs=-1, scoring='neg_root_mean_squared_error') 
gcv.fit(X, y)
pd_cv = pd.DataFrame(gcv.cv_results_)
pd_cv.head
gcv.best_params_, gcv.best_score_
# Out:
# Fitting 5 folds for each of 6 candidates, totalling 30 fits
# ({'max_features': 4}, np.float64(-4.751942056038116))

# %% [markdown]
# #  Scaling + KNN

# %%
concrete
# Out:
#       Cement  Blast    Fly  Water  Superplasticizer  Coarse   Fine  Age  \
# 0      540.0    0.0    0.0  162.0               2.5  1040.0  676.0   28
# 1      540.0    0.0    0.0  162.0               2.5  1055.0  676.0   28
# 2      332.5  142.5    0.0  228.0               0.0   932.0  594.0  270
# 3      332.5  142.5    0.0  228.0               0.0   932.0  594.0  365
# 4      198.6  132.4    0.0  192.0               0.0   978.4  825.5  360
# ...      ...    ...    ...    ...               ...     ...    ...  ...
# 1025   276.4  116.0   90.3  179.6               8.9   870.1  768.3   28
# 1026   322.2    0.0  115.6  196.0              10.4   817.9  813.4   28
# 1027   148.5  139.4  108.6  192.7               6.1   892.4  780.0   28
# 1028   159.1  186.7    0.0  175.6              11.3   989.6  788.9   28
# 1029   260.9  100.5   78.3  200.6               8.6   864.5  761.5   28
#
#       Strength
# 0        79.99
# 1        61.89
# 2        40.27
# 3        41.05
# 4        44.30
# ...        ...
# 1025     44.28
# 1026     31.18
# 1027     23.70
# 1028     32.77
# 1029     32.40
#
# [1030 rows x 9 columns]

# %%
pipe = Pipeline([('scaler',StandardScaler()),('KNN', KNeighborsRegressor())])
params = {'scaler':[None, StandardScaler(), MinMaxScaler()],
         'KNN__n_neighbors':[1,2,3,4,5,6]}

gcv = GridSearchCV(estimator=pipe, param_grid=params, cv=kfold, n_jobs=-1, scoring='neg_root_mean_squared_error') 
gcv.fit(X, y)
pd_cv = pd.DataFrame(gcv.cv_results_)
gcv.best_params_, gcv.best_score_
# Out:
# ({'KNN__n_neighbors': 3, 'scaler': StandardScaler()},
#  np.float64(-8.737696015609808))

# %%
std_scl = StandardScaler()
mm = MinMaxScaler()
knn = KNeighborsRegressor()

pipe = Pipeline([('SCL', std_scl),('KNN',knn)])
params = {'SCL':[None, std_scl, mm],
         'KNN__n_neighbors':[1,2,3,4,5,6]}

gcv = GridSearchCV(estimator=pipe, param_grid=params, cv=kfold, n_jobs=-1, scoring='neg_root_mean_squared_error') 
gcv.fit(X, y)
pd_cv = pd.DataFrame(gcv.cv_results_)
gcv.best_params_, gcv.best_score_
# Out:
# ({'KNN__n_neighbors': 3, 'SCL': StandardScaler()},
#  np.float64(-8.737696015609808))

# %%
tst = pd.read_csv(r"D:\Machine_Learning_CDAC-AI\a] Datasets\testConcrete.csv")
tst
# Out:
#     Cement  Blast  Fly  Water  Superplasticizer  Coarse  Fine  Age
# 0      495    120    0    155                 5     866   884   75
# 1      262    129    0    271                 2     808   787  174
# 2      201     48    1    215                 5     807   839  113
# 3      329    141    0    286                 1     881   823  229
# 4      354     14    0    129                 2     839   847  210
# 5      150     23   23    114                 4     883   638   36
# 6      480     64    0    292                 3     896   776  180
# 7      393     49   82    132                 1     887   830  271
# 8      284     63    1    138                 1     804   725   44
# 9      206     38    0    103                 2     818   719  191
# 10     247     64   26    175                 2     822   898  183
# 11     223    102    0    110                 2     808   854  270
# 12     457     89    0    289                 3     829   865  190
# 13     125     93    0    200                 5     893   671  113

# %% [markdown]
# ### Inferencing

# %%
# best model way
knn = KNeighborsRegressor(n_neighbors=3)
scl=StandardScaler()
bm = Pipeline([('SCL', scl),('KNN',knn)])
bm.fit(X,y)
bm.predict(tst)
# Out:
# array([57.69333333, 48.86      , 31.04      , 51.60333333, 56.81      ,
#        37.76      , 52.05666667, 39.45      , 55.62      , 54.84666667,
#        24.09333333, 67.06666667, 52.05666667, 43.24666667])

# %%
# using GCV
gcv.predict(tst)
# Out:
# array([57.69333333, 48.86      , 31.04      , 51.60333333, 56.81      ,
#        37.76      , 52.05666667, 39.45      , 55.62      , 54.84666667,
#        24.09333333, 67.06666667, 52.05666667, 43.24666667])

# %%
bm = gcv.best_estimator_
bm.predict(tst)
# Out:
# array([57.69333333, 48.86      , 31.04      , 51.60333333, 56.81      ,
#        37.76      , 52.05666667, 39.45      , 55.62      , 54.84666667,
#        24.09333333, 67.06666667, 52.05666667, 43.24666667])

# %% [markdown]
# # Housing Dataset

# %%
housing = pd.read_csv(r"D:\Machine_Learning_CDAC-AI\a] Datasets\Housing.csv")
X , y = housing.drop(['price'], axis=1), housing['price']

# %%
ohe=OneHotEncoder(drop="first")

trans = ColumnTransformer(transformers=[("OHE", ohe, make_column_selector(dtype_include=object))],     
                         remainder="passthrough", verbose_feature_names_out=False)

# %%
rf = RandomForestRegressor(random_state=26 )
pipe = Pipeline([('OHE',trans), ('RF',rf)])
rf.get_params()
# Out:
# {'bootstrap': True,
#  'ccp_alpha': 0.0,
#  'criterion': 'squared_error',
#  'max_depth': None,
#  'max_features': 1.0,
#  'max_leaf_nodes': None,
#  'max_samples': None,
#  'min_impurity_decrease': 0.0,
#  'min_samples_leaf': 1,
#  'min_samples_split': 2,
#  'min_weight_fraction_leaf': 0.0,
#  'monotonic_cst': None,
#  'n_estimators': 100,
#  'n_jobs': None,
#  'oob_score': False,
#  'random_state': 26,
#  'verbose': 0,
#  'warm_start': False}

# %%
pipe.get_params()
# Out:
# {'memory': None,
#  'steps': [('OHE', ColumnTransformer(remainder='passthrough',
#                      transformers=[('OHE', OneHotEncoder(drop='first'),
#                                     <sklearn.compose._column_transformer.make_column_selector object at 0x000002A78E351A90>)],
#                      verbose_feature_names_out=False)),
#   ('RF', RandomForestRegressor(random_state=26))],
#  'transform_input': None,
#  'verbose': False,
#  'OHE': ColumnTransformer(remainder='passthrough',
#                    transformers=[('OHE', OneHotEncoder(drop='first'),
#                                   <sklearn.compose._column_transformer.make_column_selector object at 0x000002A78E351A90>)],
#                    verbose_feature_names_out=False),
#  'RF': RandomForestRegressor(random_state=26),
#  'OHE__force_int_remainder_cols': 'deprecated',
#  'OHE__n_jobs': None,
#  'OHE__remainder': 'passthrough',
#  'OHE__sparse_threshold': 0.3,
#  'OHE__transformer_weights': None,
#  'OHE__transformers': [('OHE',
#    OneHotEncoder(drop='first'),
#    <sklearn.compose._column_transformer.make_column_selector at 0x2a78e351a90>)],
#  'OHE__verbose': False,
#  'OHE__verbose_feature_names_out': False,
#  'OHE__OHE': OneHotEncoder(drop='first'),
#  'OHE__OHE__categories': 'auto',
#  'OHE__OHE__drop': 'first',
#  'OHE__OHE__dtype': numpy.float64,
#  'OHE__OHE__feature_name_combiner': 'concat',
#  'OHE__OHE__handle_unknown': 'error',
#  'OHE__OHE__max_categories': None,
#  'OHE__OHE__min_frequency': None,
#  'OHE__OHE__sparse_output': True,
#  'RF__bootstrap': True,
#  'RF__ccp_alpha': 0.0,
#  'RF__criterion': 'squared_error',
#  'RF__max_depth': None,
#  'RF__max_features': 1.0,
#  'RF__max_leaf_nodes': None,
#  'RF__max_samples': None,
#  'RF__min_impurity_decrease': 0.0,
#  'RF__min_samples_leaf': 1,
#  'RF__min_samples_split': 2,
#  'RF__min_weight_fraction_leaf': 0.0,
#  'RF__monotonic_cst': None,
#  'RF__n_estimators': 100,
#  'RF__n_jobs': None,
#  'RF__oob_score': False,
#  'RF__random_state': 26,
#  'RF__verbose': 0,
#  'RF__warm_start': False}

# %%
# features = [2,3,4,5,6,7]
# params = {'max_features':features} # cause error due to in pipeline max_features is labeled as RF__max_features

features = [2,3,4,5,6,7]
params = {'RF__max_features':features}

gcv = GridSearchCV(estimator= pipe, param_grid=params, cv=kfold, n_jobs=-1, scoring='neg_root_mean_squared_error') 
gcv.fit(X, y)
pd_cv = pd.DataFrame(gcv.cv_results_)
gcv.best_params_, gcv.best_score_
# Out:
# ({'RF__max_features': 4}, np.float64(-1098024.9290877976))

# %% [markdown]
# # Chemical Process - Imputing

# %%
chem = pd.read_csv(r"D:\Machine_Learning_CDAC-AI\a] Datasets\ChemicalProcess.csv")
chem
# Out:
#      Yield  BiologicalMaterial01  BiologicalMaterial02  BiologicalMaterial03  \
# 0    38.00                  6.25                 49.58                 56.97
# 1    42.44                  8.01                 60.97                 67.48
# 2    42.03                  8.01                 60.97                 67.48
# 3    41.42                  8.01                 60.97                 67.48
# 4    42.49                  7.47                 63.33                 72.25
# ..     ...                   ...                   ...                   ...
# 171  39.66                  6.71                 56.32                 66.19
# 172  39.68                  6.87                 56.74                 66.61
# 173  42.23                  7.50                 58.41                 68.30
# 174  38.48                  7.53                 58.36                 69.25
# 175  39.49                  7.53                 58.36                 69.25
#
#      BiologicalMaterial04  BiologicalMaterial05  BiologicalMaterial06  \
# 0                   12.74                 19.51                 43.73
# 1                   14.65                 19.36                 53.14
# 2                   14.65                 19.36                 53.14
# 3                   14.65                 19.36                 53.14
# 4                   14.02                 17.91                 54.66
# ..                    ...                   ...                   ...
# 171                 12.35                 20.02                 50.26
# 172                 12.55                 20.18                 50.80
# 173                 13.33                 20.81                 52.96
# 174                 14.35                 20.57                 51.31
# 175                 14.35                 20.57                 51.31
#
#      BiologicalMaterial07  BiologicalMaterial08  BiologicalMaterial09  ...  \
# 0                   100.0                 16.66                 11.44  ...
# 1                   100.0                 19.04                 12.55  ...
# 2                   100.0                 19.04                 12.55  ...
# 3                   100.0                 19.04                 12.55  ...
# 4                   100.0                 18.22                 12.80  ...
# ..                    ...                   ...                   ...  ...
# 171                 100.0                 17.54                 12.50  ...
# 172                 100.0                 17.48                 12.41  ...
# 173                 100.0                 17.23                 12.04  ...
# 174                 100.0                 17.87                 12.77  ...
# 175                 100.0                 17.87                 12.77  ...
#
#      ManufacturingProcess36  ManufacturingProcess37  ManufacturingProcess38  \
# 0                     0.019                     0.5                       3
# 1                     0.019                     2.0                       2
# 2                     0.018                     0.7                       2
# 3                     0.018                     1.2                       2
# 4                     0.017                     0.2                       2
# ..                      ...                     ...                     ...
# 171                     NaN                     2.3                       0
# 172                     NaN                     1.0                       0
# 173                     NaN                     1.3                       0
# 174                     NaN                     2.3                       0
# 175                     NaN                     0.9                       0
#
#      ManufacturingProcess39  ManufacturingProcess40  ManufacturingProcess41  \
# 0                       7.2                     NaN                     NaN
# 1                       7.2                     0.1                    0.15
# 2                       7.2                     0.0                    0.00
# 3                       7.2                     0.0                    0.00
# 4                       7.3                     0.0                    0.00
# ..                      ...                     ...                     ...
# 171                     0.0                     0.0                    0.00
# 172                     0.0                     0.0                    0.00
# 173                     0.0                     0.0                    0.00
# 174                     0.0                     0.0                    0.00
# 175                     0.0                     0.0                    0.00
#
#      ManufacturingProcess42  ManufacturingProcess43  ManufacturingProcess44  \
# 0                      11.6                     3.0                     1.8
# 1                      11.1                     0.9                     1.9
# 2                      12.0                     1.0                     1.8
# 3                      10.6                     1.1                     1.8
# 4                      11.0                     1.1                     1.7
# ..                      ...                     ...                     ...
# 171                     0.0                     0.6                     0.0
# 172                     0.0                     0.6                     0.0
# 173                     0.0                     0.6                     0.0
# 174                     0.0                     0.5                     0.0
# 175                     0.0                     0.6                     0.0
#
#      ManufacturingProcess45
# 0                       2.4
# 1                       2.2
# 2                       2.3
# 3                       2.1
# 4                       2.1
# ..                      ...
# 171                     0.0
# 172                     0.0
# 173                     0.0
# 174                     0.0
# 175                     0.0
#
# [176 rows x 58 columns]

# %%
X, y = chem.drop('Yield', axis=1) , chem['Yield']

# %%
imp = SimpleImputer()
rf = RandomForestRegressor(random_state=26)
pipe = Pipeline([('IMP',imp),('MODEL',rf)])

params = {'IMP__strategy':['mean', 'median'],
         'MODEL__max_features':[2,5,10,15,25,30]}

gcv = GridSearchCV(estimator= pipe, param_grid=params, cv=kfold, n_jobs=-1, scoring='neg_root_mean_squared_error') 
gcv.fit(X, y)
pd_cv = pd.DataFrame(gcv.cv_results_)
gcv.best_params_, gcv.best_score_
# Out:
# ({'IMP__strategy': 'median', 'MODEL__max_features': 30},
#  np.float64(-1.1026080480472165))

# %%
imp = SimpleImputer(strategy='mean')
rf = RandomForestRegressor(random_state=26)
pipe = Pipeline([('IMP',imp),('MODEL',rf)])

params = {'MODEL__max_features':[2,5,10,15,25,30]}

gcv = GridSearchCV(estimator= pipe, param_grid=params, cv=kfold, n_jobs=-1, scoring='neg_root_mean_squared_error') 
gcv.fit(X, y)
pd_cv = pd.DataFrame(gcv.cv_results_)
gcv.best_params_, gcv.best_score_
# Out:
# ({'MODEL__max_features': 25}, np.float64(-1.1101464968009211))

# %%
imp = SimpleImputer(strategy='median')
rf = RandomForestRegressor(random_state=26)
pipe = Pipeline([('IMP',imp),('MODEL',rf)])

params = {'MODEL__max_features':[2,5,10,15,25,30]}

gcv = GridSearchCV(estimator= pipe, param_grid=params, cv=kfold, n_jobs=-1, scoring='neg_root_mean_squared_error') 
gcv.fit(X, y)
pd_cv = pd.DataFrame(gcv.cv_results_)
gcv.best_params_, gcv.best_score_
# Out:
# ({'MODEL__max_features': 30}, np.float64(-1.1026080480472165))
