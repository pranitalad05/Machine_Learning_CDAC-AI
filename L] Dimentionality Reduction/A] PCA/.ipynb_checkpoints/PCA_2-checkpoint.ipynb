# %%
import pandas as pd
import numpy as np
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
from pca import pca
import matplotlib.pyplot as plt
import os
os.chdir(r"D:\Machine_Learning_CDAC-AI\a] Datasets")
import warnings
warnings.filterwarnings('ignore')

# %%
nut = pd.read_csv(r"D:\Machine_Learning_CDAC-AI\a] Datasets\nutrient.csv", index_col=0)
nut.shape
# Out:
# (27, 5)

# %%
scaler = StandardScaler().set_output(transform='pandas')
nut_scaled = scaler.fit_transform(nut)

# %%
prcomp = PCA().set_output(transform='pandas')
pc_data = prcomp.fit_transform(nut_scaled)
pc_data.var()   #PC0 > PC1 > .....> PC4
# Out:
# pca0    2.280797
# pca1    1.189962
# pca2    0.880318
# pca3    0.839567
# pca4    0.001663
# dtype: float64

# %%
pc_data
# Out:
#                          pca0      pca1      pca2      pca3      pca4
# Food_Item
# BEEF BRAISED         1.894907  0.318029 -0.003579  0.327156  0.005915
# HAMBURGER            0.659812 -0.079563 -0.512841  0.166202 -0.002632
# BEEF ROAST           2.936755  1.122724  1.097788 -0.226335  0.003483
# BEEF STEAK           2.321069  0.585663  0.239173  0.318095  0.028400
# BEEF CANNED         -0.256477  0.054382 -1.168707  0.474857 -0.042641
# CHICKEN BROILED     -0.932996 -0.905719 -0.393767 -0.815849 -0.031897
# CHICKEN CANNED      -0.185016 -1.564189 -0.789681  0.039419 -0.015362
# BEEF HEART          -0.699024  0.346282 -2.595080  1.568667  0.045738
# LAMB LEG ROAST       0.937389  0.108904 -0.274877  0.082978 -0.024877
# LAMB SHOULDER ROAST  1.409838  0.415262  0.211434 -0.137797 -0.042680
# SMOKED HAM           1.903069  0.269835  0.034079  0.294673  0.005207
# PORK ROAST           1.924870  0.453141  0.164663  0.180407 -0.032956
# PORK SIMMERED        2.089779  0.435920  0.244768  0.189606  0.010358
# BEEF TONGUE          0.139724  0.231166 -0.241602 -0.409972 -0.025657
# VEAL CUTLET         -0.126633 -0.606239 -0.983172  0.204163  0.023817
# BLUEFISH BAKED      -0.684565 -1.587139 -0.119651 -0.622858 -0.007018
# CLAMS RAW           -2.388947  2.720309 -0.606162  0.077535  0.033059
# CLAMS CANNED        -2.612097  3.070873 -0.042609 -0.741773 -0.050294
# CRABMEAT CANNED     -1.462484 -0.244363  0.695135 -1.566693 -0.000690
# HADDOCK FRIED       -0.788883 -0.625519  0.518010 -1.488127  0.078415
# MACKEREL BROILED     0.216685 -0.679264  0.168090 -0.810376 -0.033912
# MACKEREL CANNED     -1.189782  0.084699  1.345458  0.265016 -0.016102
# PERCH FRIED         -0.106700 -0.079860  0.417400 -1.046451  0.133917
# SALMON CANNED       -1.535433 -0.713151  1.533960 -0.065717 -0.046296
# SARDINES CANNED     -1.838944 -0.556404  2.240747  3.138110  0.026409
# TUNA CANNED         -0.137351 -1.708566 -0.719237 -0.101814 -0.017693
# SHRIMP CANNED       -1.488563 -0.867213 -0.459742  0.706879 -0.004010

# %%
values, vectors = np.linalg.eig(nut_scaled.cov())
print("Eigen Values: ",values)
# Out:
# Eigen Values:  [2.28079741e+00 1.66325132e-03 1.18996245e+00 8.39566765e-01
#  8.80317810e-01]

# %%
vectors
# Out:
# array([[-0.65428251, -0.7092977 , -0.08533006,  0.19703438, -0.15068976],
#        [-0.15073191,  0.10406865,  0.68933242,  0.52649179,  0.46268437],
#        [-0.63991067,  0.69710352, -0.19978707,  0.13170953, -0.21748273],
#        [ 0.35497845, -0.00316007,  0.00314436,  0.67057536, -0.65138247],
#        [ 0.11704241, -0.01015761, -0.69109684,  0.46579517,  0.54001659]])

# %%
prcomp.components_
# Out:
# array([[ 0.65428251,  0.15073191,  0.63991067, -0.35497845, -0.11704241],
#        [ 0.08533006, -0.68933242,  0.19978707, -0.00314436,  0.69109684],
#        [ 0.15068976, -0.46268437,  0.21748273,  0.65138247, -0.54001659],
#        [ 0.19703438,  0.52649179,  0.13170953,  0.67057536,  0.46579517],
#        [ 0.7092977 , -0.10406865, -0.69710352,  0.00316007,  0.01015761]])

# %%
model = pca()
results = model.fit_transform(nut_scaled,
                             col_labels = nut.columns,
                             row_labels = list(nut.index))
model.biplot(label=True, legend=True)
for i in np.arange(0, nut.shape[0]):
    plt.text(pc_data.values[i,0],
            pc_data.values[i,1],
            list(nut.index)[i])
plt.show()
# Out:
# [27-06-2026 15:59:37] [pca.pca] [INFO] PCA reduction performed to capture at least 95.0% explained variance using 5 columns of the input data.
# [27-06-2026 15:59:37] [pca.pca] [INFO] Fit using PCA.
# [27-06-2026 15:59:37] [pca.pca] [INFO] Compute loadings and PCs.
# [27-06-2026 15:59:37] [pca.pca] [INFO] Compute explained variance.
# [27-06-2026 15:59:37] [pca.pca] [INFO] The top 4 principal component(s) explains >= 95.00% of the explained variance.
# [27-06-2026 15:59:37] [pca.pca] [INFO] The PCA reduction is performed on 5 variables (columns) of the input dataframe.
# [27-06-2026 15:59:37] [pca.pca] [INFO] Fit using PCA.
# [27-06-2026 15:59:37] [pca.pca] [INFO] Compute loadings and PCs.
# [27-06-2026 15:59:37] [pca.pca] [INFO] Outlier detection using Hotelling T2 test with alpha=[0.05] and n_components=[4]
# [27-06-2026 15:59:37] [pca.pca] [INFO] Multiple test correction applied for Hotelling T2 test: [fdr_bh]
# [27-06-2026 15:59:37] [pca.pca] [INFO] Outlier detection using SPE/DmodX with n_std=[3]
# [27-06-2026 15:59:37] [pca.pca] [WARNING] Parameter <label> is deprecated and will not be supported in future version.
# [27-06-2026 15:59:37] [pca.pca] [INFO] Plot PC1 vs PC2 with loadings.
# [27-06-2026 15:59:37] [scatterd.scatterd] [INFO] Create scatterplot

# %% [markdown]
# ## USAArrest Dataset

# %%
usa = pd.read_csv(r"D:\Machine_Learning_CDAC-AI\a] Datasets\USArrests.csv", index_col=0)
usa.head()
# Out:
#             Murder  Assault  UrbanPop  Rape
# Alabama       13.2      236        58  21.2
# Alaska        10.0      263        48  44.5
# Arizona        8.1      294        80  31.0
# Arkansas       8.8      190        50  19.5
# California     9.0      276        91  40.6

# %%
scaler = StandardScaler().set_output(transform='pandas')
usa_scaled = scaler.fit_transform(usa)

# %%
prcomp = PCA().set_output(transform='pandas')
pc_data = prcomp.fit_transform(usa_scaled)
pc_data.var()   #PC0 > PC1 > .....> PC4
# Out:
# pca0    2.530859
# pca1    1.009964
# pca2    0.363840
# pca3    0.176969
# dtype: float64

# %%
model = pca()
results = model.fit_transform(usa_scaled,
                             col_labels = usa.columns,
                             row_labels = list(usa.index))
model.biplot(label=True, legend=True)
for i in np.arange(0, usa.shape[0]):
    plt.text(pc_data.values[i,0],
            pc_data.values[i,1],
            list(usa.index)[i])
plt.show()
# Out:
# [27-06-2026 15:59:40] [pca.pca] [INFO] PCA reduction performed to capture at least 95.0% explained variance using 4 columns of the input data.
# [27-06-2026 15:59:40] [pca.pca] [INFO] Fit using PCA.
# [27-06-2026 15:59:40] [pca.pca] [INFO] Compute loadings and PCs.
# [27-06-2026 15:59:40] [pca.pca] [INFO] Compute explained variance.
# [27-06-2026 15:59:40] [pca.pca] [INFO] The top 3 principal component(s) explains >= 95.00% of the explained variance.
# [27-06-2026 15:59:40] [pca.pca] [INFO] The PCA reduction is performed on 4 variables (columns) of the input dataframe.
# [27-06-2026 15:59:40] [pca.pca] [INFO] Fit using PCA.
# [27-06-2026 15:59:40] [pca.pca] [INFO] Compute loadings and PCs.
# [27-06-2026 15:59:40] [pca.pca] [INFO] Outlier detection using Hotelling T2 test with alpha=[0.05] and n_components=[3]
# [27-06-2026 15:59:40] [pca.pca] [INFO] Multiple test correction applied for Hotelling T2 test: [fdr_bh]
# [27-06-2026 15:59:40] [pca.pca] [INFO] Outlier detection using SPE/DmodX with n_std=[3]
# [27-06-2026 15:59:40] [pca.pca] [WARNING] Parameter <label> is deprecated and will not be supported in future version.
# [27-06-2026 15:59:40] [pca.pca] [INFO] Plot PC1 vs PC2 with loadings.
# [27-06-2026 15:59:40] [scatterd.scatterd] [INFO] Create scatterplot
